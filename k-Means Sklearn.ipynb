# %% [markdown]
# ## k-Means utilizando Sklearn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
# %matplotlib inline

# %% [markdown]
# ## Base de dados :

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)
#data

# %% [markdown]
# ## Visualizando a base de dados :

# %%
plt.scatter(data[0][:,0],data[0][:,1])#,c=data[1],cmap='rainbow')

# %% [markdown]
# ## Algoritmo k-means com Sklearn :

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# ## Centróides calculados :

# %%
kmeans.cluster_centers_
# Out:
# array([[-4.13591321,  7.95389851],
#        [-9.46941837, -6.56081545],
#        [-0.0123077 ,  2.13407664],
#        [ 3.71749226,  7.01388735]])

# %% [markdown]
# ## Clusters associados :

# %%
kmeans.labels_
# Out:
# array([0, 3, 2, 3, 3, 1, 3, 2, 3, 2, 0, 2, 3, 3, 0, 2, 3, 2, 1, 0, 1, 2,
#        2, 1, 0, 1, 1, 2, 3, 3, 0, 1, 3, 2, 2, 0, 1, 1, 1, 2, 1, 0, 0, 0,
#        2, 3, 0, 2, 1, 2, 2, 0, 3, 2, 1, 0, 2, 2, 0, 3, 1, 3, 1, 0, 3, 2,
#        1, 3, 3, 1, 3, 2, 1, 2, 1, 3, 3, 2, 0, 2, 2, 1, 3, 1, 2, 2, 2, 0,
#        2, 1, 1, 1, 1, 2, 2, 1, 3, 0, 1, 3, 2, 1, 2, 2, 3, 2, 1, 3, 1, 1,
#        3, 0, 0, 3, 1, 3, 0, 0, 3, 0, 2, 0, 2, 0, 2, 3, 0, 2, 1, 0, 0, 0,
#        2, 1, 1, 0, 3, 0, 3, 2, 1, 3, 1, 0, 0, 3, 2, 1, 0, 0, 0, 0, 2, 3,
#        2, 0, 3, 3, 3, 2, 3, 2, 2, 0, 1, 0, 2, 3, 0, 2, 3, 2, 0, 3, 2, 0,
#        3, 3, 1, 3, 0, 1, 1, 0, 1, 1, 1, 1, 1, 2, 1, 3, 3, 0, 1, 2, 3, 3,
#        1, 2], dtype=int32)

# %%
kmeans.n_iter_
# Out:
# 4

# %% [markdown]
# ## Valor da função 'Elbow' para o valor de k escolhido:

# %%
print('O valor da função Elbow para k =', kmeans.n_clusters, 'é', kmeans.inertia_)
# Out:
# O valor da função Elbow para k = 4 é 1318.4035725547483

# %% [markdown]
# ## Visualização dos clusters associados :

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('k-Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
plt.plot([2, 3, 4, 6, 8, 10, 20],[3799, 2288, 1318, 996, 754, 619, 278])
plt.xlabel('k')
plt.ylabel('Função Elbow')
# Out:
# Text(0, 0.5, 'Função Elbow')
